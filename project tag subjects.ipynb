# %%
import pandas as pd
import os

# %%
pwd
# Out:
# '/Users/shivanisankar/Desktop'

# %%
df = pd.read_csv("zendesk_tickets_tag_subjects.csv")
print(df)
# Out:
#       Ticket Requesters User ID Ticket Requesters Client Name  \
# 0                             4                      Plaid Co
# 1                             4                      Plaid Co
# 2                             4                      Plaid Co
# 3                             4                      Plaid Co
# 4                             4                      Plaid Co
# 5                             4                      Plaid Co
# 6                             4                      Plaid Co
# 7                             4                      Plaid Co
# 8                             3                  Keyence Corp
# 9                             3                  Keyence Corp
# 10                            3                  Keyence Corp
# 11                           61                      Opsgenie
# 12                           61                      Opsgenie
# 13                            6                          zola
# ...

# %%
df1 = df.iloc[:,3:6]

# %%
df1.groupby('unique key').first()
# Out:
#                                                  Zendesk Ticket Tags Category  \
# unique key
# (MUN) Nguyet Nguyenhonestbee                                        front-end
# A-csinghalexpediagco                                                      NaN
# A-csinghalexpediagco-embed                                                NaN
# ABHISHEK SRIVASTAVAacrotrend                                            admin
# AHMAD ASSAFBeamery                                                first-timer
# AJ HongResy                                                               dev
# AJ Lawrenceceros                                                    front-end
# ALYSON LAgithub                                                         learn
# AMARO Biz Devamaro                                                        dev
# AMARO People Analyticsamaro                                         front-end
# AMY ANTHONYsendgrid                                               self-served
# ...
