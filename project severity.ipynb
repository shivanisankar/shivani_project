# %%
import pandas as pd
import os

# %%
pwd
# Out:
# '/Users/shivanisankar/Desktop'

# %%
df = pd.read_csv("zendesk_tickets_severity.csv")
print(df)
# Out:
#        Zendesk Tickets Historical Severity  Zendesk Tickets Zendesk ID
# 0                                      NaN                      229290
# 1                                      NaN                      222479
# 2                                      NaN                        2143
# 3                                      NaN                         361
# 4                                      NaN                        1036
# 5                                      NaN                         610
# 6                                      NaN                       10564
# 7                                      NaN                        2041
# 8                                      NaN                         746
# 9                                      NaN                         160
# 10                                     NaN                        1610
# 11                                     NaN                         793
# ...

# %%
df.groupby('Zendesk Tickets Historical Severity').nunique()
# Out:
#                                      Zendesk Tickets Historical Severity  \
# Zendesk Tickets Historical Severity
# S1                                                                     1
# S2                                                                     1
# S3                                                                     1
# S4                                                                     1
#
#                                      Zendesk Tickets Zendesk ID
# Zendesk Tickets Historical Severity
# S1                                                         1313
# S2                                                         3599
# S3                                                        23719
# S4                                                       160491

# %%
total_not_null = 160491+23719+3599+1313
# Out:
# 189122

# %%
null = 340304-189122
# Out:
# 151182

# %%
df1 = pd.read_csv("zendesk_tickets_severity_by_user2.csv")
print(df1)
# Out:
#                       Unnamed: 0                  Unnamed: 1  \
# 0      Ticket Requesters User ID      Ticket Requesters Name
# 1                              4                       尚博 岡田
# 2                              3                       優駿 黒岩
# 3                             61            Çağdaş Başaraner
# 4                              6               zola Bailliez
# 5                              9                         zma
# 6                             52                    zian sun
# 7                              6               zaynul abadin
# 8                              1                zLabels GmbH
# 9                             79                     youngin
# 10                           618                   yixin sun
# 11                            45              yazid louenchi
# 12                            35                yazhen xiang
# 13                            35                yazhen xiang
# ...

# %%
df1.groupby('Zendesk Tickets Historical Severity').first()
# Out:
#                                                  Unnamed: 0  \
# Zendesk Tickets Historical Severity
# (MUN) Nguyet Nguyenhonestbee                            877
# ABHISHEK SRIVASTAVAacrotrend                              9
# AHMAD ASSAFBeamery                                        3
# AJ HongResy                                               5
# AJ Lawrenceceros                                         44
# ALYSON LAgithub                                        4264
# AMARO Biz Devamaro                                       66
# AMARO People Analyticsamaro                              57
# AMY ANTHONYsendgrid                                      57
# ANAND ARULARASUtml                                        1
# ANGIE BROWNredpill                                       19
# ANKIT RAHEJAUpwork                                      603
# APARNA JAYASURIYANgoodappledigital                      217
# API Teamgiphy                                             5
# ...
